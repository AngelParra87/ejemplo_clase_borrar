# %% [markdown]
# <a href="https://colab.research.google.com/github/AngelParra87/ejemplo_clase_borrar/blob/main/Ruta/BorradorClase1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
1 + 1 + 1 + 1 + 1 + 1
# Out:
# 6

# %% [markdown]
# # Este es un titulo![Captura de pantalla_20221028_145620.png](data:image/png;base64,...)

# %% [markdown]
# DMC Online:	<img src="data:image/jpeg;base64,..." alt="HTML5 Icon" width="600" height="350" >
